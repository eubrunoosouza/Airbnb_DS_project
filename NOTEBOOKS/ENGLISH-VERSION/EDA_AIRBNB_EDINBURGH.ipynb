# %% [markdown]
# <a href="https://colab.research.google.com/github/eubrunoosouza/Airbnb_DS_project/blob/main/EDA_AIRBNB_EDINBURGH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### ***Exploratory Data Analysis***
# *by Bruno C. Souza - Data Science | Digital Mkt | Engineering*
#
# ---
#
# <img alt="Colaboratory logo" width="80%" src="https://github.com/eubrunoosouza/Airbnb_DS_project/blob/96560cb37c808def137523f24ed3738972f9ea60/MISC/EDIMBURGO.png?raw=true">
#
# # ***Analysis of Airbnb Data (Edinburgh/Scotland).***
#
#
# [Airbnb](https://www.airbnb.com.br/) is one of the **largest companies in the hospitality industry today**. The main detail is that, following the same line as other technology giants, **does not own any hotel**!
#
# Its main focus is to connect people who want to travel, and obviously stay, with local hosts who want to rent their properties in a practical way, without so much bureaucracy. Airbnb provides an innovative platform to carry out all this exchange between *hosts* and *guests*.
#
# By the end of 2018, the Startup, founded about 10 years ago, had already hosted more than **300 million people** around the world, challenging traditional hotel chains..
#
# A very cool initiative by Airbnb is the availability of real data from some of the main cities in the world, from its platform. This is possible through the **portal**: [Inside Airbnb](http://insideairbnb.com/get-the-data.html), where it is possible to directly download a large amount of data to develop Data Science projects and solutions.
#
# *This project was only possible because this initiative! Thanks!*

# %% [markdown]
# # **Why Edinburgh?**
# The choice of this particular city, among many others provided by the Airbnb portal, was motivated by the simple fact that, at the time of elaborating this project, she was carrying out a music theory distance course, by the University of Edinburgh. Decide to combine the useful with the pleasant, because in addition to being an Engineer and Data Scientist, I'm also a musician, and that **for over 10 years**.
#
# > I love classical music, because of the difficulty, and in my free time, I study piano. I find this sharpens my mind and improves my focus, concentration and hand-eye coordination.
#
# <img alt="Colaboratory logo" width="35%" src="https://github.com/eubrunoosouza/Airbnb_DS_project/blob/96560cb37c808def137523f24ed3738972f9ea60/MISC/piano-player-small.jpg?raw=true">

# %% [markdown]
# # **Let's see Edinburgh?**
#
# ## _What is the magic behind this Scottish town?_
#
#
# First of all, Edinburgh is a very attractive city, and this is because it is a city full of **medieval** history.
#
# The place, which belongs to the United Kingdom and borders England, offers a magnificent natural landscape, beautiful castles and Gothic buildings. In addition to their famous whiskey!
#
# Much more than its beauties, Scotland has a rich past that has been told in the series *“Outlander”*.
#
# One of the highlights of the city, literally speaking, is Edinburgh Castle _(the castle pictured above)_. This castle is an old fortress that draws a lot of attention in the city, as it is located on top of a large mountain, the **Castle Rock** _(Rochedo do Castelo)_.
#
# The Castle is very large and there are many dependencies within it, such as Scotland's **National War Museum**, which includes a large number of military artifacts.
#
# Undoubtedly, it is one of the most important castles in the country, receiving annually about **one million people**.<br><br>
#
# <img alt="Colaboratory logo" width="50%" src="https://github.com/eubrunoosouza/data_science/blob/main/381838154-outlander.jpg?raw=true">
#
# ---

# %% [markdown]
# ## **How ​​was the data obtained?**
#
# The data were obtained through the Portal
# : [Inside Airbnb](http://insideairbnb.com/get-the-data.html).
#
# *For this initial analysis, only the following file will be downloaded:*
#
# `listings.csv` - Summary information and metrics for listings in Edinburgh (good for visualizations).<br><br>
#
#
# > **IMPORTANT:** The portal is constantly being updated, and at some point, it could be that the dataset used in this notebook is no longer available, which would break our code.
#
#
# With this in mind, I made it available [here in this link](https://www.dropbox.com/s/uw7kzs25e0wn7iu/listings.csv?dl=1) the dataset that was used, so that you can always use this material.<br><br>
#
#
# With all that in mind, let's start this **exploratory data analysis**!

# %%
# importing the "folium" geospatial library.

# !pip install folium -q

# %%
# import the necessary packages.

import folium
import pandas as pd
from folium import plugins
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import the listings.csv file into a DataFrame.

df = pd.read_csv('https://www.dropbox.com/s/uw7kzs25e0wn7iu/listings.csv?dl=1')

# %% [markdown]
# ## **Raw Data Analysis**
#
# This initial step aims to explore the *dataset* and extract initial information, in order to have a situational notion of the raw data. The way they are distributed, dimensionality, etc.<br><br>
#
# Primarily, I would like to present a **basic summary** of the variables present in this database:<br><br>
#
#
# **DICTIONARY OF VARIABLES:**
#
# * `id` - generated id number to identify the property.
# * `name` - description of the name of the property advertised on the AirBnB platform.
# * `host_id` - id number of the owner (host) of the property.
# * `host_name` - name of the property's host.
# * `neighbourhood_group` - this column does not contain any valid values.
# * `neighbourhood` - name of the neighborhood/neighborhood of the locality.
# * `number_of_reviews` - ​​total number of reviews.
# * `number_of_reviews_ltm` - number of reviews (last 12 months).
# * `latitude` - coordinate of the property's latitude.
# * `license` - license, registration number.
# * `longitude` - longitude coordinate of the property.
# * `room_type` - information about the type of room offered.
# * `price` - rental price of the property.
# * `minimum_nights` - number of minimum nights of accommodation.
# * `last_review` - date the property was last evaluated.
# * `reviews_per_month` - number of reviews per month.
# * `calculated_host_listings_count` - number of properties from the same host.
# * `availability_365` - Number of days of availability to rent the property within 365 days.<br><br>
#
# First of all, it is very important to check the 'face' of our *dataset*, **analyzing the first 5 entries**.<br><br>
#
# Come on!

# %%
# show first 5 entries

df.head()
# Out:
#       id                                               name  host_id  \
# 0  15420                  Georgian Boutique Apt City Centre    60423
# 1  24288  Cool central Loft, sleeps 4, 2 double bed+en-s...    46498
# 2  38628                              Edinburgh Holiday Let   165635
# 3  44552                  Double room - spacious Leith flat   195950
# 4  54188                            The Four Sisters Boatel   253850
#
#    host_name  neighbourhood_group                              neighbourhood  \
# 0  Charlotte                  NaN  Old Town, Princes Street and Leith Street
# 1     Gordon                  NaN       Canongate, Southside and Dumbiedykes
# 2      Trish                  NaN                                      Joppa
# 3      Shaun                  NaN                                South Leith
# 4    Natalie                  NaN                   Dalry and Fountainbridge
#
#    latitude  longitude        room_type  price  minimum_nights  \
# ...

# %% [markdown]
# ### **How ​​many attributes (variables) and entries does the dataset have? And the types?**
#
# Well, let's see how many **entries**(*read lines*) our _dataset_ has, and we'll also check the **columns** present.
#
# It is worth mentioning that this dataset we are using is a **"abridged"** version of *Airbnb*. On the same *Airbnb* portal, where we downloaded the `listings.csv` file, there is also a more complete version a: `listings.csv.gz`. A more robust version with more variables.

# %%
# identifying the DataFrame data volume

print("This dataset has:\t {} entries".format(df.shape[0]))
print("This dataset has:\t {} columns\n".format(df.shape[1]))

# dataframe types

display(df.dtypes)
# Out:
# This dataset has:	 6146 entries
# This dataset has:	 18 columns
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group               float64
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                           float64
# dtype: object

# %% [markdown]
# ### **What is the percentage of missing values ​​in the *dataset*?**
#
# It is necessary to do a preliminary analysis, after importing the dataset, in order to map the missing or null data. With that in hand, we have a better sense of the quality of the _dataset_.
#
# **_Below we will see the percentages of null data, per column, in relation to the total entries._**
#
#
# * You can see that the `neighbourhood_group` and `license` columns have **100%** of their missing values, null.
# * Next we have that the variables `last_review` and `reviews_per_month` have little more than **10%** of their null values.
# * The `host_name` variable has a very small amount of missing data.

# %%
# sort variables in descending order by their missing values
(df.isnull().sum() / df.shape[0]).sort_values(ascending=False)
# Out:
# license                           1.000000
# neighbourhood_group               1.000000
# reviews_per_month                 0.111292
# last_review                       0.111292
# host_name                         0.000325
# minimum_nights                    0.000000
# number_of_reviews_ltm             0.000000
# availability_365                  0.000000
# calculated_host_listings_count    0.000000
# number_of_reviews                 0.000000
# id                                0.000000
# name                              0.000000
# room_type                         0.000000
# longitude                         0.000000
# latitude                          0.000000
# neighbourhood                     0.000000
# host_id                           0.000000
# price                             0.000000
# dtype: float64

# %% [markdown]
# ### **How ​​are numeric variables distributed?**
# To get an initial look at how the numeric variables are distributed, I'll plot a *histogram* of the numeric variables.

# %%
# plot the histogram of numeric variables

df.hist(bins=15, grid=False, figsize=(20,15), zorder=2, rwidth=0.5);

# %% [markdown]
# ### **Preliminary conclusions after histogram plotting:**
#
# * The `minimum_nights` and `price` columns, which respectively represent the **minimum number of nights** and the **rent price**, both have a very atypical distribution, we will check this further below.

# %% [markdown]
# ## Verification of Outliers Existence.
#
# Checking outliers is an extremely important step, as they can **compromise** and **bias** our exploratory analysis, causing us to reach the wrong conclusions about the data.

# %%
# outlier check

df[['price','minimum_nights','number_of_reviews','reviews_per_month',
   'calculated_host_listings_count','availability_365']].describe()
# Out:
#               price  minimum_nights  number_of_reviews  reviews_per_month  \
# count   6146.000000     6146.000000        6146.000000        5462.000000
# mean     184.488773        4.364302          61.985519           2.013213
# std      729.983800       30.909509          92.770313           2.892681
# min        0.000000        1.000000           0.000000           0.010000
# 25%       58.000000        1.000000           4.000000           0.450000
# 50%       89.000000        2.000000          23.000000           1.300000
# 75%      135.000000        3.000000          82.000000           2.757500
# max    17921.000000     1124.000000         831.000000          77.000000
#
#        calculated_host_listings_count  availability_365
# count                      6146.00000       6146.000000
# mean                          7.03547        131.059551
# std                          17.34203        125.357151
# min                           1.00000          0.000000
# ...

# %% [markdown]
# ### **Preliminary Conclusions:**
# Looking at the statistical summary above, we can confirm the existence of outliers and we can raise some hypotheses such as:
#
# * The `price` variable has **75%** of the value below **135**, but its maximum value is **17921**.
# * The minimum number of nights (`minimum_nights`) is above **365 days** in the year. More precisely **1124 nights**.<br><br>
#
# To handle the **outliers** present in the _dataset_, the following steps will be adopted:
#
# 1. _Define the **Q1** and **Q3** for the variables that will be cleared._
# 2. _Calculate the **IQR** for the variables._
# 3. _Set the **upper** and **lower** limit to cut out the outliers._
# 4. _Remove the **outliers**._

# %% [markdown]
# ## Identifying outliers and box plot plotting for `price`.
#
# We will start by checking the limits for `price` and, with a boxplot plot, we will visually analyze the *outliers* present in the variable's distribution.

# %%
# identifying outliers for prices (price).

q1_price = df.price.quantile(.25)
q3_price = df.price.quantile(.75)
IQR_price = q3_price - q1_price

print('price IQR {} '.format(IQR_price))

# setting the limits for price.

superior_limit_price = q3_price + 1.5 * IQR_price
inferior_limit_price = q1_price - 1.5 * IQR_price

print('price superior limit: {}'.format(superior_limit_price))
print('price inferior limit: {}'.format(inferior_limit_price))
# Out:
# price IQR 77.0
# price superior limit: 250.5
# price inferior limit: -57.5

# %%
# boxplot plot for 'price'.

fig, ax = plt.subplots(figsize=(15,3))
df.price.plot(kind='box', vert=False);
ax.set_title('Boxplot for price')

# see the amount of values ​​above the upper limit for price

print("The dataset in question has {} entries in total.".format(df.shape[0]))

print("{} entries are above the upper limit of {} for the 'price' variable."
      .format(len(df[df.price > superior_limit_price]),superior_limit_price))

print("This corresponds to {:.2f}% of column entries in relation to the total.\n"
      .format((len(df[df.price > superior_limit_price]) / df.shape[0])*100))
# Out:
# The dataset in question has 6146 entries in total.
# 481 entries are above the upper limit of 250.5 for the 'price' variable.
# This corresponds to 7.83% of column entries in relation to the total.

# %% [markdown]
# ## Identifying outliers and box plot plotting for `minimum_nights`.
#
# As was done for the `price` variable, we will also check the limits for `minimum_nights`, and with a boxplot plot, we will visually analyze the outliers present in the distribution of the variable in question.

# %%
# identifying outliers for minimum_nights.

q1_min_nights = df.minimum_nights.quantile(.25)
q3_min_nights = df.minimum_nights.quantile(.75)
IQR_min_nights = q3_min_nights - q1_min_nights

print('IQR for minimum_nights {} '.format(IQR_min_nights))

# setting the limits to minimum_nights.

sup_limit_min_nights = q3_min_nights + 1.5 * IQR_min_nights
inf_limit_min_nights = q1_min_nights - 1.5 * IQR_min_nights

print('minimum_nights superior limit: {}'.format(sup_limit_min_nights))
print('minimum_nights inferior limit: {}'.format(inf_limit_min_nights))
# Out:
# IQR for minimum_nights 2.0
# minimum_nights superior limit: 6.0
# minimum_nights inferior limit: -2.0

# %%
# boxplot plot for 'minimum_nights'.

fig, ax = plt.subplots(figsize=(15,3))
df.minimum_nights.plot(kind='box', vert=False);
ax.set_title('Boxplot for minimum_nights')

# see the amount of values ​​above the upper limit for minimum_nights.

print("Total dataset entries = {}".format(df.shape[0]))
print("{} entries above superior limit 'minimum_nights' = {}".format(len(df[df.minimum_nights 
      > sup_limit_min_nights]),sup_limit_min_nights))
print("This corresponds to {:.2f}% of our dataset.\n".format((len(df[df.minimum_nights 
      > sup_limit_min_nights]) / df.shape[0])*100))
# Out:
# Total dataset entries = 6146
# 310 entries above superior limit 'minimum_nights' = 6.0
# This corresponds to 5.04% of our dataset.

# %% [markdown]
# ## **Data Cleaning**
#
# It is important to note that columns with **low predictive power** and **large amount of missing data** can be excluded.
#
# This is the case for the variables: `neighbourhood_group`, `license`, `reviews_per_month` and `last_review`.
#
# ***Let's proceed with cleaning this data.***

# %%
# dropping columns with non-relevant null data

df_clean = df.copy()
df_clean.drop(['neighbourhood_group', 'license'], axis=1, inplace=True)

# removing outliers

df_clean.drop(df_clean[df_clean.minimum_nights > sup_limit_min_nights].index, 
              axis=0, inplace=True)

df_clean.drop(df_clean[df_clean.price > superior_limit_price].index, 
              axis=0, inplace=True)


# Null data check after initial cleanup

display(df_clean.isnull().sum().sort_values(ascending=False) / df_clean.shape[0])
# Out:
# last_review                       0.091568
# reviews_per_month                 0.091568
# host_name                         0.000371
# id                                0.000000
# name                              0.000000
# host_id                           0.000000
# neighbourhood                     0.000000
# latitude                          0.000000
# longitude                         0.000000
# room_type                         0.000000
# price                             0.000000
# minimum_nights                    0.000000
# number_of_reviews                 0.000000
# calculated_host_listings_count    0.000000
# availability_365                  0.000000
# number_of_reviews_ltm             0.000000
# dtype: float64

# %% [markdown]
# > I chose to remove the null values ​​in `reviews_per_month, last_review and host_name`, as these data are irrelevant to my exploratory analysis.

# %%
# clearing the missing null data

df_clean.dropna(axis=0, inplace=True)

# final dataset clean check

display(df_clean.isnull().sum().sort_values(ascending=False) / df_clean.shape[0])
# Out:
# id                                0.0
# name                              0.0
# host_id                           0.0
# host_name                         0.0
# neighbourhood                     0.0
# latitude                          0.0
# longitude                         0.0
# room_type                         0.0
# price                             0.0
# minimum_nights                    0.0
# number_of_reviews                 0.0
# last_review                       0.0
# reviews_per_month                 0.0
# calculated_host_listings_count    0.0
# availability_365                  0.0
# number_of_reviews_ltm             0.0
# dtype: float64

# %%
# checking dataset shrink size after cleanup

reducao_de_entradas = ((df.shape[0] - df_clean.shape[0]) / df.shape[0])*100
reducao_de_variaveis = ((df.shape[1] - df_clean.shape[1]) / df.shape[1])*100

print('Before Data Cleaning: {} entries and {} variables.'
      .format(df.shape[0], df.shape[1]))

print('After Data Cleaning: {} entries and {} variables.\n'
      .format(df_clean.shape[0], df_clean.shape[1]))

print('Reduction of {:.2f}% in entries.'
      .format(reducao_de_entradas))

print('Reduction of {:.2f}% in variables.'
      .format(reducao_de_variaveis))
# Out:
# Before Data Cleaning: 6146 entries and 18 variables.
# After Data Cleaning: 4890 entries and 16 variables.
#
# Reduction of 20.44% in entries.
# Reduction of 11.11% in variables.

# %% [markdown]
# ## **Summary of what was done in this cleaning**
# 1. We removed the `license` and `neighbourhood_group` columns, because they are not relevant for the exploratory analysis and also because they have **100%** of missing values.
# 2. Removed the outliers present in `minimum_nights` and `price`.
# 3. Removal of null values ​​in `reviews_per_month, last_review and host_name`, as these data are irrelevant.

# %%
# plotting the histogram of numeric variables after cleaning

df_clean.hist(bins=15, grid=False, figsize=(20,15), zorder=2, rwidth=0.5);

# %% [markdown]
# ## **Plotting boxplots after cleaning and removing outliers**

# %%
# Boxplot graph for 'price'.

fig, ax = plt.subplots(figsize=(15,3))
df_clean.price.plot(kind='box', vert=False);
ax.set_title("Boxplot graph for 'price' - Dataset after cleaning");

# %%
# Boxplot graph for 'minimum_nights'.

fig, ax = plt.subplots(figsize=(15,3))
df_clean.minimum_nights.plot(kind='box', vert=False);
ax.set_title("Boxplot graph for 'minimum_nights' - Dataset after cleaning");

# %% [markdown]
# ### **What would be average rental prices in Edinburgh?**
# After all this cleaning process, we can check the average prices in pounds in the city.

# %%
# see the average of the `price` column

price_mean = df_clean.price.mean()

print("The average price in Edinburgh is £{:.2f}".format(price_mean))
# Out:
# The average price in Edinburgh is £91.92

# %% [markdown]
# ### **What is the correlation between the variables?**
# Now we will check the correlation of the variables present in the dataset.

# %%
# create a correlation matrix
corr = df_clean[['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month',
    'calculated_host_listings_count', 'availability_365']].corr()

# show the correlation matrix
display(corr)
# Out:
#                                    price  minimum_nights  number_of_reviews  \
# price                           1.000000        0.128330          -0.081695
# minimum_nights                  0.128330        1.000000          -0.034379
# number_of_reviews              -0.081695       -0.034379           1.000000
# reviews_per_month              -0.023945       -0.100546           0.401886
# calculated_host_listings_count  0.155458       -0.061249          -0.082557
# availability_365                0.161741       -0.125296           0.076587
#
#                                 reviews_per_month  \
# price                                   -0.023945
# minimum_nights                          -0.100546
# number_of_reviews                        0.401886
# reviews_per_month                        1.000000
# calculated_host_listings_count           0.003656
# availability_365                         0.045600
#
#                                 calculated_host_listings_count  \
# ...

# %%
# plot a heatmap from the correlations

sns.heatmap(corr, cmap='RdBu', fmt='.2f', square=True, linecolor='white', annot=True);

# %% [markdown]
# > Variables in general have **low correlation**, but there is a significant correlation, as expected, between `number_of_reviews` and `reviews_per_months`.

# %% [markdown]
# ### **Which category of property is most rented on Airbnb in Edinburgh?**
# We can easily check this. See the code below:

# %%
# What type of property is the most rented?

fig, ax = plt.subplots(figsize= (13,7))

df_clean.room_type.value_counts(ascending=True).plot(kind='barh');

ax.set_ylabel('')
ax.set_xlabel('')

plt.text(1700, 0.3, 'Most rented property categories',
          fontsize=17, 
          color="#A2A1A3",
          weight='bold');

plt.text(1700, 0, 'Highlighted Entire home/apt\n'
                    'and Private room, most rented categories.',
          fontsize=12, 
          color="#A2A1A3");

i=0

for p in ax.patches:
    ax.text(p.get_width()+ 50,i+p.get_height()/90,'{:,} rents'.format(int(p.get_width())))
    i+=1

ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)

plt.xticks([])
plt.tight_layout()

# %%
# show the amount of each type of property available
 
most_frequent_rent = df_clean.room_type.value_counts()

print("The most rented type of property is the 'Entire home/apt' com {}"
      .format(most_frequent_rent[0]))
# Out:
# The most rented type of property is the 'Entire home/apt' com 3399

# %%
# show the percentage of each property type available
 
df.room_type.value_counts() / df.shape[0]
# Out:
# Entire home/apt    0.673283
# Private room       0.307029
# Hotel room         0.015457
# Shared room        0.004230
# Name: room_type, dtype: float64

# %% [markdown]
# ### **What is the most expensive location in the dataset?**

# %%
# defining colors
GREY01, GREY02, GREY03= "#CFCDCE", "#A2A1A3", "#787878"

# graph plotting
fig, ax = plt.subplots(figsize= (13,7))
n_plots = 10
palette = sns.color_palette("coolwarm", n_colors=n_plots)

with palette:
  # see prices by neighborhoods, on average
  ax = df_clean.groupby(['neighbourhood'])['price'].mean().sort_values(ascending=True)[101:].plot.barh()

  # plot title
  plt.text(-2, 11.5, 'Most Expensive Locations in Edinburgh',
          fontsize=18, 
          color=GREY03,
          weight='bold')

  # plot subtitle
  plt.text(-2, 11.3,
          "The average prices of the most expensive neighborhoods in\n"
          "the city ​​of Edinburgh, according to Airbnb dataset.",
          verticalalignment="top",
          fontsize=14,
          color=GREY02)

  initialx=0

  # remove grid
  ax.spines['right'].set_visible(False)
  ax.spines['left'].set_visible(False)
  ax.spines['top'].set_visible(False)
  ax.spines['bottom'].set_visible(False)

  # remover titles
  ax.set_ylabel('')    
  ax.set_xlabel('')

  plt.tick_params(
    axis='both',         
    which='both',     
    bottom=False,      
    top=False,         
    labelbottom=False) 
    
  # add labels
  for p in ax.patches:
    ax.text(p.get_width(),initialx+p.get_height()/8,'{:1.0f}'.format(p.get_width()))
    initialx+=1
  plt.show()

# %% [markdown]
# > **The neighborhoods with the highest average prices in the city would be:**
# 1. *Carrick Knowe*
# 2. *New Town West*

# %% [markdown]
# ### **What is the cheapest dataset locale?**
# Below is an illustrative chart of the cheapest locations.

# %%
# graph plotting
fig, ax = plt.subplots(figsize= (13,7))
n_plots = 10
palette = sns.color_palette("coolwarm", n_colors=n_plots)

with palette:
  # see prices by neighborhoods, on average
  ax = df_clean.groupby(['neighbourhood'])['price'].mean().sort_values(ascending=False)[101:].plot.barh()

  # plot title
  plt.text(-2, 11.5, 'Cheapest Locations in Edinburgh',
          fontsize=18, 
          color=GREY03,
          weight='bold')

  # plot subtitle
  plt.text(-2, 11.3,
          "Average prices of the cheapest neighborhoods in\n"
          "the Edinburgh city, according to Airbnb dataset.",
          verticalalignment="top",
          fontsize=14,
          color=GREY02)

  initialx=0

  # remove grid
  ax.spines['right'].set_visible(False)
  ax.spines['left'].set_visible(False)
  ax.spines['top'].set_visible(False)
  ax.spines['bottom'].set_visible(False)

  # remove titles
  ax.set_ylabel('')    
  ax.set_xlabel('')

  plt.tick_params(
    axis='both',         
    which='both',     
    bottom=False,      
    top=False,         
    labelbottom=False) 
    
  # add labels
  for p in ax.patches:
    ax.text(p.get_width(),initialx+p.get_height()/8,'{:1.0f}'.format(p.get_width()))
    initialx+=1
  plt.show()

# %% [markdown]
# > **The neighborhoods with the lowest average prices in the city would be:**
# 1. *Clovenstone and Wester Hailes*
# 2. *Niddrie*

# %%
# Check the number of properties in the first 2 neighborhoods

print(df_clean[df_clean.neighbourhood == 'Carrick Knowe'].shape)
print(df_clean[df_clean.neighbourhood == 'New Town West'].shape)
print(df_clean[df_clean.neighbourhood == 'Clovenstone and Wester Hailes'].shape)
print(df_clean[df_clean.neighbourhood == 'Niddrie'].shape)
# Out:
# (5, 16)
# (174, 16)
# (4, 16)
# (9, 16)

# %% [markdown]
# ## **Distribution by Latitute and Longitude based on Prices**
# > The scatter plot below, plotted as a function of latitudes and longitudes, shows us a very reasonable distribution of prices along the territorial extension of the city. With a greater accumulation of properties, and also higher prices in the center of the map, region close to ***Edinburgh castle***.

# %%
# plot properties by latitude-longitude

df_clean.plot(kind='scatter', x='longitude', y='latitude', alpha=0.4, c=df_clean['price'], s=8,
              cmap=plt.get_cmap('jet'), figsize=(12,8));

# %%
# using folium for an interactive map

edinburgh_map = folium.Map(location=[55.9494, -3.16028], zoom_start= 10)

coordinates= []
for x, y in zip(df_clean.latitude, df_clean.longitude):
    coordinates.append([x,y])
    
edinburgh_map.add_child(plugins.MarkerCluster(coordinates))

edinburgh_map

# to view the generated map, open this notebook in google colab.
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %% [markdown]
# <img alt="Colaboratory logo" width="100%" src="https://github.com/eubrunoosouza/Airbnb_DS_project/blob/a952daf3871e92fa4194017239c9b93d0095cc15/MISC/PREVIEW-FOLIUM.png?raw=true">

# %% [markdown]
# ### **What is the average minimum rental nights (minimum_nights)?**

# %%
# see the average of the `minimum_nights`` column

media_noites_minimas = df_clean.minimum_nights.mean()

print("The average minimum nights rental is about {:.2f} nights".format(media_noites_minimas))
# Out:
# The average minimum nights rental is about 2.07 nights

# %% [markdown]
# ## **Conclusions and Insights**
#
# Briefly, we can conclude that:
#
# * In relation to the *original dataset*, after cleaning, we reduced a percentage of **20.44% in the entries**.
# * In relation to the *original dataset*, after cleaning, we reduced a percentage of **11.11% in the variables**.
# * The *average* rental prices in the city are around **£91.92**.
# * The *neighborhoods* with the highest average prices in the city would be: **Carrick Knowe** and **New Town West**. Highlight this last neighborhood, as it is close to tourist attractions in the city. The neighborhoods with the lowest average prices in the city would be: **Clovenstone and Wester Hailes** and **Niddrie**.
# * The average *minimum nights* in the city is around **2 nights**.<br><br>
# Finally, I believe that this exploratory analysis obtained reasonable results and is in agreement with the reality of the city, in terms of tourism.
# In a future analysis, I will use the most complete dataset available by Airbnb.<br><br>
#
# _**Thanks for your time!**_ 🙂

# %% [markdown]
# ---
